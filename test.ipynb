# %%
import os
from dotenv import load_dotenv

load_dotenv()

LANGCHAIN_TRACING_V2 = os.getenv('LANGCHAIN_TRACING_V2')
LANGSMITH_API_KEY = os.getenv('LANGSMITH_API_KEY')
ANTHROPIC_API_KEY = os.getenv('ANTHROPIC_API_KEY')
LANGSMITH_ENDPOINT = os.getenv('LANGSMITH_ENDPOINT')

# %%
LANGSMITH_ENDPOINT
# Out:
# 'https://eu.api.smith.langchain.com'

# %%
LANGSMITH_API_KEY
# Out:
# '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'

# %%
# Create a LANGSMITH_API_KEY in Settings > API Keys
from langsmith import Client
client = Client(api_url=LANGSMITH_ENDPOINT, api_key=LANGSMITH_API_KEY)
#prompt = client.pull_prompt("wfh/convo-optimizer", include_model=True)
prompt = client.pull_prompt("simpsun347/hatedetection:9992070a", include_model=False)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/GitHub/tweet-critic/.venv/lib/python3.11/site-packages/langsmith/utils.py:159, in raise_for_status_with_text(response)
#     158 try:
# --> 159     response.raise_for_status()
#     160 except requests.HTTPError as e:
#
# File ~/Documents/GitHub/tweet-critic/.venv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/commits/simpsun347/hatedetection/9992070a
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# ...

# %%
from langchain import hub as prompts
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("tell me a joke about {topic}")
url = prompts.push("joke-generator", prompt)
# url is a link to the prompt in the UI
print(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/GitHub/tweet-critic/.venv/lib/python3.11/site-packages/langsmith/utils.py:159, in raise_for_status_with_text(response)
#     158 try:
# --> 159     response.raise_for_status()
#     160 except requests.HTTPError as e:
#
# File ~/Documents/GitHub/tweet-critic/.venv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://eu.api.smith.langchain.com/repos/-/joke-generator
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# ...

# %%
# Debug pulling a prompt
import traceback
import langchain
from langchain import hub as prompts

print("langchain version:", getattr(langchain, "__version__", "unknown"))

# quick internet test
import requests
try:
    r = requests.get("https://www.google.com", timeout=5)
    print("Internet OK (google.com) status:", r.status_code)
except Exception as e:
    print("Internet check failed:", e)

# try to pull and show full error
try:
    prompt = prompts.pull("wfh/tweet-critic-fewshot:2988f48d", api_url=LANGSMITH_ENDPOINT, api_key=LANGSMITH_API_KEY)
    print("Pulled prompt type:", type(prompt))
    print(prompt)
except Exception as e:
    print("Error pulling prompt:", e)
    traceback.print_exc()
# Out:
# langchain version: 0.3.27
# Internet OK (google.com) status: 200
# Error pulling prompt: Failed to GET /commits/wfh/tweet-critic-fewshot/2988f48d in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/commits/wfh/tweet-critic-fewshot/2988f48d', '{"error":"Forbidden"}\n')
# Traceback (most recent call last):
#   File "/Users/toni/Documents/GitHub/tweet-critic/.venv/lib/python3.11/site-packages/langsmith/utils.py", line 159, in raise_for_status_with_text
#     response.raise_for_status()
#   File "/Users/toni/Documents/GitHub/tweet-critic/.venv/lib/python3.11/site-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/commits/wfh/tweet-critic-fewshot/2988f48d
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
# ...

# %%
# Create a LANGSMITH_API_KEY in Settings > API Keys
from langsmith import Client
client = Client(api_url=LANGSMITH_ENDPOINT, api_key=LANGSMITH_API_KEY)
prompt = client.pull_prompt("wfh/tweet-critic-fewshot:2988f48d",include_model=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/GitHub/tweet-critic/.venv/lib/python3.11/site-packages/langsmith/utils.py:159, in raise_for_status_with_text(response)
#     158 try:
# --> 159     response.raise_for_status()
#     160 except requests.HTTPError as e:
#
# File ~/Documents/GitHub/tweet-critic/.venv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/commits/wfh/tweet-critic-fewshot/2988f48d?include_model=true
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# ...
